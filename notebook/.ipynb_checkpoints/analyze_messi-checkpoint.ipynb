# %% [markdown]
# 新規データメッシの過去のイベントの解析

# %% [markdown]
# # 準備

# %% [markdown]
# ## 必要なライブラリのインポート

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image

import statsbomb as sb

# %% [markdown]
# ## 綺麗なグラフを描画するための関数定義

# %%
def draw_graph():
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,7))

    # 軸の色の設定
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('grey')
    ax.spines['left'].set_color('darkgrey')
    ax.spines['right'].set_color('none')
    ax.tick_params(axis = 'x', colors ='grey')
    ax.tick_params(axis = 'y', colors = 'darkgrey')
    ax.xaxis.label.set_color('grey')

    return fig, ax

# %%
plt.rcParams["font.size"] = 12
# 文字カラーを白に
COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

# %%
color_list = ['#004D98', '#A50044', '#EDBB00', '#DB0030', '#FFED02', '#000000']

# %% [markdown]
# ## ピッチの描画

# %%
twitter_color = '#141d26'
COLOR = 'white'

XMAX, XMIN = 120, 0
YMAX, YMIN = 80, 0

def draw_pitch(title=None, outfilepath=None):
    fig, ax = plt.subplots(figsize=(10, 7), facecolor=twitter_color)
    
    im = image.imread(os.path.join('..','fig','FC_Barcelona.png'))
    fig.figimage(im, 245, 150, alpha=.3)
    
    fig.patch.set_facecolor('#141d26')
    ax.patch.set_facecolor('#141d26')

    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(False)

    ax.plot([0,120], [0, 0], color=COLOR)
    ax.plot([120,120], [0, 80], color=COLOR)
    ax.plot([120,0], [80,80], color=COLOR)
    ax.plot([0, 0], [80, 0], color=COLOR)
    ax.plot([60, 60], [0, 80], color=COLOR)
    ax.plot([0, 0], [36, 44], color=COLOR, linewidth=10)
    ax.plot([120, 120], [36, 44], color=COLOR, linewidth=10)

#         ax.scatter(60, 40, color='black')
    centreCircle = plt.Circle((60, 40), 12, color=COLOR, fill=False)
    ax.add_patch(centreCircle)

    ax.plot([0, 18],  [18, 18], color=COLOR)
    ax.plot([18, 18],  [18, 62], color=COLOR)
    ax.plot([18, 0],  [62, 62], color=COLOR)
    ax.plot([0, 6],  [30, 30], color=COLOR)
    ax.plot([6, 6],  [30, 50], color=COLOR)
    ax.plot([6, 0],  [50, 50], color=COLOR)
#         ax.scatter(12, 40, color='black')

    ax.plot([120, 102],  [18, 18], color=COLOR)
    ax.plot([102, 102],  [18, 62], color=COLOR)
    ax.plot([102, 120],  [62, 62], color=COLOR)
    ax.plot([120, 114],  [30, 30], color=COLOR)
    ax.plot([114, 114],  [30, 50], color=COLOR)
    ax.plot([114, 120],  [50, 50], color=COLOR)
#         ax.scatter(108, 40, color='black')
    ax.set_ylim(ax.get_ylim()[::-1])

    ax.tick_params(bottom=False, left=False, labelbottom=False, labelleft=False)

    if title: ax.set_title(title)
    if outfilepath: plt.savefig(outfilepath, bbox_inches='tight', facecolor=twitter_color)

    return fig, ax

# %%
draw_pitch()
# Out:
# (<Figure size 720x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xb53282160>)

# %% [markdown]
# ## コンペティションの確認

# %%
comps = sb.Competitions()
comps.get_dataframe()
# Out:
#    competition_gender  competition_id         competition_name  \
# 0              female              37  FA Women's Super League
# 1                male              43           FIFA World Cup
# 2                male              11                  La Liga
# 3                male              11                  La Liga
# 4                male              11                  La Liga
# 5                male              11                  La Liga
# 6                male              11                  La Liga
# 7                male              11                  La Liga
# 8                male              11                  La Liga
# 9                male              11                  La Liga
# 10               male              11                  La Liga
# 11               male              11                  La Liga
# 12               male              11                  La Liga
# 13               male              11                  La Liga
# ...

# %% [markdown]
# ## 試合の確認

# %%
comps_df = comps.get_dataframe()
competition_id = comps_df[comps_df.competition_name == 'La Liga'].competition_id.unique()[0]

for i, season_id in enumerate(comps_df[comps_df.competition_id == competition_id].season_id.tolist()):
    matches_df_tmp = sb.Matches(event_id=competition_id, season_id=season_id).get_dataframe()
    if i == 0:
        matches_df = matches_df_tmp
    else:
        matches_df = pd.concat([matches_df, matches_df_tmp])

matches_df.reset_index(inplace=True)
matches_df.head()
# Out:
#    index  away_score away_team competition  \
# 0      0           8       217          11
# 1      1           0       216          11
# 2      2           1       213          11
# 3      3           0       214          11
# 4      4           2       217          11
#
#                      competition_stage  home_score home_team      kick_off  \
# 0  {'id': 1, 'name': 'Regular Season'}           0       219  20:00:00.000
# 1  {'id': 1, 'name': 'Regular Season'}           6       217  16:00:00.000
# 2  {'id': 1, 'name': 'Regular Season'}           2       217  20:30:00.000
# 3  {'id': 1, 'name': 'Regular Season'}           5       217  17:00:00.000
# 4  {'id': 1, 'name': 'Regular Season'}           2       222  16:00:00.000
#
#               last_updated  match_date  match_id match_status  match_week  \
# 0  2019-07-24T16:57:09.139  2016-04-20    266310    available          34
# 1  2019-07-24T15:24:14.040  2016-03-12    266498    available          29
# ...

# %%
home_team_name_list, away_team_name_list = [], []
for idx in matches_df.index.values:
    lineups = sb.Lineups(str(matches_df.loc[idx, 'match_id']))
    lineups_df = lineups.get_dataframe()
    home_team_name = lineups_df[lineups_df.team_id == matches_df.loc[idx, 'home_team']].team_name.values[0]
    away_team_name = lineups_df[lineups_df.team_id == matches_df.loc[idx, 'away_team']].team_name.values[0]
    
    home_team_name_list.append(home_team_name); away_team_name_list.append(away_team_name)
    
matches_df['home_team_name'] = home_team_name_list
matches_df['away_team_name'] = away_team_name_list
matches_df.head()
# Out:
#    index  away_score away_team competition  \
# 0      0           8       217          11
# 1      1           0       216          11
# 2      2           1       213          11
# 3      3           0       214          11
# 4      4           2       217          11
#
#                      competition_stage  home_score home_team      kick_off  \
# 0  {'id': 1, 'name': 'Regular Season'}           0       219  20:00:00.000
# 1  {'id': 1, 'name': 'Regular Season'}           6       217  16:00:00.000
# 2  {'id': 1, 'name': 'Regular Season'}           2       217  20:30:00.000
# 3  {'id': 1, 'name': 'Regular Season'}           5       217  17:00:00.000
# 4  {'id': 1, 'name': 'Regular Season'}           2       222  16:00:00.000
#
#               last_updated  match_date  match_id match_status  match_week  \
# 0  2019-07-24T16:57:09.139  2016-04-20    266310    available          34
# 1  2019-07-24T15:24:14.040  2016-03-12    266498    available          29
# ...

# %% [markdown]
# ## データの確認

# %%
from tqdm import tqdm
from tqdm._tqdm_notebook import tqdm_notebook 

for i, match_id in tqdm(enumerate(matches_df.match_id)):
    try:
        events = sb.Events(str(match_id))
        event_df_tmp = pd.concat([events.get_dataframe(event_type='shot'), events.get_dataframe(event_type='pass'), events.get_dataframe(event_type='dribble')])
        event_df_tmp['match_id'] = match_id

        if i == 0:
            event_df = event_df_tmp
        else:
            event_df = pd.concat([event_df, event_df_tmp])
    except:
        print(match_id)
# Out:
# 0it [00:00, ?it/s]/Users/yamamuros83/.pyenv/versions/anaconda3-5.3.1/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys
# 348it [12:59,  2.54s/it]

# %%
event_df.dtypes
# Out:
# angle               float64
# assisted_shot_id     object
# body_part            object
# cross                object
# cut_back             object
# deflected            object
# duration            float64
# end_location_x      float64
# end_location_y      float64
# end_location_z      float64
# event_type           object
# first_time           object
# follows_dribble      object
# goal_assist          object
# height               object
# id                   object
# index                 int64
# key_pass_id          object
# length              float64
# minute                int64
# miscommunication     object
# nutmeg               object
# off_camera           object
# one_on_one           object
# open_goal            object
# outcome              object
# overrun              object
# pass_backheel        object
# period                int64
# play_pattern         object
# player               object
# position             object
# possession            int64
# ...

# %% [markdown]
# # 集計

# %%
event_df_messi = pd.merge(event_df[event_df.player.str.contains('Messi')], matches_df[['match_id', 'season']], on='match_id')
summary_messi = event_df_messi.groupby(['season', 'event_type']).size()

summary_messi = summary_messi.unstack('event_type')
# summary_messi.columns = ['season_id', 'event_type', 'cnt']

summary_messi_tmp = event_df_messi.groupby('season').match_id.unique().reset_index()
summary_messi_tmp['number of games'] = summary_messi_tmp.match_id.apply(lambda x: len(x))

summary_messi = pd.merge(summary_messi, summary_messi_tmp[['season', 'number of games']], left_index=True, right_on='season')

summary_messi.set_index('season', inplace=True)

summary_messi = pd.merge(summary_messi, comps.get_dataframe()[['season_id', 'season_name']], left_index=True, right_on='season_id')

summary_messi.drop('season_id', axis=True, inplace=True)
summary_messi.set_index('season_name', inplace=True)
summary_messi.sort_index(inplace=True)

c_list = summary_messi.columns.tolist()[:-1]

summary_messi.loc[:, c_list] = summary_messi.apply(lambda xs: xs/ xs[-1], axis=1)

# %% [markdown]
# # シンプルな可視化

# %% [markdown]
# ## 1試合あたりのアクション数

# %%
twitter_color = '#141d26'

plt.rcParams["font.size"] = 12
# 文字カラーを白に
COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

fig, ax = plt.subplots(figsize=(16/1.5,9/1.5), facecolor=twitter_color)
summary_messi.iloc[1:, :-1].plot.barh(stacked=True, ax=ax, alpha=0.8, color=['#EDBB00', '#004D98', '#A50044'])

# タイトル
ax.set_title('Leo Meessi\'s Event Data Summary in La Liga via statsbomb')

# 背景色を黒に
fig.patch.set_facecolor(twitter_color)
ax.patch.set_facecolor(twitter_color)

# 3. y軸の順番を逆に
ax.invert_yaxis()

# 4. 四方の枠(spines)を消す
[spine.set_visible(False) for spine in ax.spines.values()]

# 以下でも可能kgrey
# sides = ['left', 'right', 'top', 'bottom']
# [ax.spines[side].set_visible(False) for side in sides] 

# 5. y軸x軸のtickを消す

# 6. x軸のtick label(10000など)を消す
ax.tick_params(bottom=False, left=False, labelbottom=False)

# 7. y軸のラベルサイズを大きく
# ax.tick_params(axis='y', labelsize='large', color='grey')

# 8. バーの右側に実際の値を表示
vmax = summary_messi.iloc[1:, :-1].sum(axis=1).max()
for i, value in enumerate(summary_messi.iloc[1:, :-1].sum(axis=1)):
    ax.text(value+vmax*0.01, i, f'{value:.1f}', va='center')
    
# 9. 
for i, vs in enumerate(summary_messi.iloc[1:, :-1].values):
    for j, v in enumerate(vs):
        ax.text(vs[:j].sum()+0.1, i, f'{v:.1f}', va='center', ha='left', fontsize=10)
    
# legendの背景色の設定
ax.legend(facecolor=twitter_color)

plt.xlabel('average count of actions per 1 game')

plt.savefig(os.path.join('..', 'fig', 'stackedBarh_countOfActions.png'), bbox_inches='tight', facecolor=twitter_color)

# %% [markdown]
# ## 1試合あたりのアクション数（not stacked）

# %%
plt.rcParams["font.size"] = 12
# 文字カラーを白に
COLOR = 'white'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

fig, ax = plt.subplots(figsize=(16/1.5,9/1.5), facecolor=twitter_color)
summary_messi.iloc[1:, :-1].plot.barh(ax=ax, alpha=0.8, color=['#EDBB00', '#004D98', '#A50044'], width=0.8)

# タイトル
ax.set_title('Leo Meessi\'s Event Data Summary in La Liga via statsbomb')

# 背景色を黒に
fig.patch.set_facecolor('#141d26')
ax.patch.set_facecolor('#141d26')

# 3. y軸の順番を逆に
ax.invert_yaxis()

# 4. 四方の枠(spines)を消す
[spine.set_visible(False) for spine in ax.spines.values()]

# 以下でも可能kgrey
# sides = ['left', 'right', 'top', 'bottom']
# [ax.spines[side].set_visible(False) for side in sides] 

# 5. y軸x軸のtickを消す
# 6. x軸のtick label(10000など)を消す
ax.tick_params(bottom=False, left=False, labelbottom=False)

# 7. y軸のラベルサイズを大きく
# ax.tick_params(axis='y', labelsize='large', color='grey')

# 8. バーの右側に実際の値を表示
for i, vs in enumerate(summary_messi.iloc[1:, :-1].values):
    for j, v in enumerate(vs):
        ax.text(v*1.01, i-0.3 if j == 0 else i+0.3if j==2 else i, f'{v:.1f}', va='center', ha='left')

ax.legend(facecolor="#141d26")

plt.xlabel('average count of actions per 1 game')

plt.savefig(os.path.join('..', 'fig', 'barh_countOfActions.png'), bbox_inches='tight', facecolor=twitter_color)

# %% [markdown]
# # outcomeの集計・可視化

# %% [markdown]
# ## 集計

# %%
event_df_messi = pd.merge(event_df[event_df.player.str.contains('Messi')], matches_df[['match_id', 'season']], on='match_id').fillna('Complete')

summary_messi = event_df_messi.groupby(['season', 'event_type', 'outcome']).size().reset_index().set_index('season')

summary_messi.rename({0: 'cnt'}, axis=1, inplace=True)

# summary_messi = pd.merge(summary_messi, comps.get_dataframe()[['season_id', 'season_name']], left_index=True, right_on='season_id')

# summary_messi.drop('season_id', axis=True, inplace=True)
# summary_messi.set_index('season_name', inplace=True)
# summary_messi.sort_index(inplace=True)

# %%
summary_game_tmp = event_df_messi.groupby('season').match_id.unique().reset_index()
summary_game_tmp['number of games'] = summary_game_tmp.match_id.apply(lambda x: len(x))
summary_game_tmp.drop('match_id', axis=1, inplace=True)

# %% [markdown]
# ## 可視化

# %%
for event_type in summary_messi.event_type.unique():
    fig, ax = plt.subplots(figsize=(16/1.5,9/1.5), facecolor=twitter_color)
    
    summary_messi_tmp = summary_messi[summary_messi.event_type==event_type].pivot_table(values=['cnt'], index=['season'], columns=['outcome'])
    summary_messi_tmp.columns = [c[1] for c in summary_messi_tmp.columns.tolist()]
    
    summary_messi_tmp = pd.merge(summary_messi_tmp, summary_game_tmp[['season', 'number of games']], left_index=True, right_on='season')

    summary_messi_tmp.set_index('season', inplace=True)

    summary_messi_tmp = pd.merge(summary_messi_tmp, comps.get_dataframe()[['season_id', 'season_name']], left_index=True, right_on='season_id')

    summary_messi_tmp.drop('season_id', axis=True, inplace=True)
    summary_messi_tmp.set_index('season_name', inplace=True)
    summary_messi_tmp.sort_index(inplace=True)

    c_list = summary_messi_tmp.columns.tolist()[:-1]

    summary_messi_tmp.loc[:, c_list] = summary_messi_tmp.apply(lambda xs: xs/ xs[-1], axis=1)
    
    summary_messi_tmp.iloc[1:,:-1].plot.barh(stacked=True, ax=ax, color=color_list)
    ax.set_title(f'Leo Meessi\'s {event_type} Data Summary in La Liga via statsbomb')

    # 背景色を黒に
    fig.patch.set_facecolor(twitter_color)
    ax.patch.set_facecolor(twitter_color)

    # 3. y軸の順番を逆に
    ax.invert_yaxis()

    # 4. 四方の枠(spines)を消す
    [spine.set_visible(False) for spine in ax.spines.values()]

    # 以下でも可能kgrey
    # sides = ['left', 'right', 'top', 'bottom']
    # [ax.spines[side].set_visible(False) for side in sides] 

    # 5. y軸x軸のtickを消す

    # 6. x軸のtick label(10000など)を消す
    ax.tick_params(bottom=False, left=False, labelbottom=False)

    # 7. y軸のラベルサイズを大きく
    # ax.tick_params(axis='y', labelsize='large', color='grey')

    # 8. バーの右側に実際の値を表示
    vmax = summary_messi_tmp.iloc[1:,:-1].sum(axis=1).max()
    for i, value in enumerate(summary_messi_tmp.iloc[1:,:-1].sum(axis=1)):
        ax.text(value+vmax*0.01, i, f'{value:.1f}', va='center')

    # 9. 
    """
    for i, vs in enumerate(summary_messi_tmp.iloc[1:, :-1].values):
        for j, v in enumerate(vs):
            ax.text(vs[:j].sum()+0.1, i, f'{v:}', va='center', ha='left', fontsize=10)
    """
    
    # legendの背景色の設定
    ax.legend(facecolor=twitter_color)

    plt.xlabel('average count of outcome per 1 game')
    
    plt.savefig(os.path.join(f'stackedBarh_avg_count_outcomes.png'), bbox_inches='tight', facecolor=twitter_color)

# %% [markdown]
# # メッシのイベントデータの平均地点を可視化

# %% [markdown]
# ## 集計

# %%
event_df_messi = pd.merge(event_df[event_df.player.str.contains('Messi')], matches_df[['match_id', 'season']], on='match_id')

summary_messi = event_df_messi.groupby(['season']).agg({'start_location_x':'mean', 'start_location_y':'mean'})

summary_messi = pd.merge(summary_messi, comps.get_dataframe()[['season_id', 'season_name']], left_index=True, right_on='season_id')

summary_messi.drop('season_id', axis=True, inplace=True)
summary_messi.set_index('season_name', inplace=True)
summary_messi.sort_index(inplace=True)

# %% [markdown]
# ## 可視化

# %%
color_dict = {'dribble':'#EDBB00', 'pass':'#004D98', 'shot':'#A50044'}

# %%
fig, ax = draw_pitch(title=f'Leo Meessi\'s Avg location in La Liga via statsbomb')


for i, (x, y) in enumerate(summary_messi[['start_location_x', 'start_location_y']].values):
    season_str = '/'.join([season_str_tmp[2:] for season_str_tmp in summary_messi.index.tolist()[i].split('/')])
    ax.annotate(xy=[x,y], color=color_dict['dribble'], s=season_str, fontsize=10)
#     ax.set_ylim(ax.get_ylim()[::-1])

plt.savefig(os.path.join('..','fig',f'avg_location.png'), bbox_inches='tight', facecolor=twitter_color)

# %% [markdown]
# ## 集計

# %%
event_df_messi = pd.merge(event_df[event_df.player.str.contains('Messi')], matches_df[['match_id', 'season']], on='match_id')

summary_messi = event_df_messi.groupby(['season', 'event_type']).agg({'start_location_x':'mean', 'start_location_y':'mean'}).unstack('event_type')

summary_messi = pd.merge(summary_messi, comps.get_dataframe()[['season_id', 'season_name']], left_index=True, right_on='season_id')

summary_messi.drop('season_id', axis=True, inplace=True)
summary_messi.set_index('season_name', inplace=True)
summary_messi.sort_index(inplace=True)
# Out:
# /Users/yamamuros83/.pyenv/versions/anaconda3-5.3.1/envs/py36/lib/python3.6/site-packages/pandas/core/reshape/merge.py:522: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 可視化

# %%
color_dict = {'dribble':'#EDBB00', 'pass':'#004D98', 'shot':'#A50044'}

# %%
for k, v in color_dict.items():
    fig, ax = draw_pitch(title=f'Leo Meessi\'s Avg {k} location in La Liga via statsbomb')
    
    for i, (x, y) in enumerate(summary_messi[[('start_location_x',k), ('start_location_y',k)]].values):
        season_str = '/'.join([season_str_tmp[2:] for season_str_tmp in summary_messi.index.tolist()[i].split('/')])
        ax.annotate(xy=[x,y], color=v, s=season_str, fontsize=10)
    
    plt.savefig(os.path.join('..','fig',f'avg_{k}_location.png'), bbox_inches='tight', facecolor=twitter_color)

# %% [markdown]
# # メッシの各シーズンのヒートマップを可視化

# %% [markdown]
# ## 集計

# %%
event_df_messi = pd.merge(event_df[event_df.player.str.contains('Messi')], matches_df[['match_id', 'season']], on='match_id')
event_df_messi.set_index('season', inplace=True)

# summary_messi = event_df_messi.groupby(['season']).agg({'start_location_x':'mean', 'start_location_y':'mean'})

event_df_messi = pd.merge(event_df_messi, comps.get_dataframe()[['season_id', 'season_name']], left_index=True, right_on='season_id')

event_df_messi.drop('season_id', axis=True, inplace=True)
# summary_messi.set_index('season_name', inplace=True)
# summary_messi.sort_index(inplace=True)

# %% [markdown]
#  ## 可視化

# %%
from scipy.stats.kde import gaussian_kde

season_list = np.sort(event_df_messi.season_name.unique()).tolist()
season_list_list = [season_list[:3], season_list[3:6], season_list[6:9], [season_list[9]], season_list[10:]]

def convert_season_name(season_name):
    return '-'.join([season_name_tmp[2:] for season_name_tmp in season_name.split('/')])

for season_list in season_list_list:
    x, y = event_df_messi[event_df_messi.season_name.isin(season_list)][['start_location_x', 'start_location_y']].values.T
    k = gaussian_kde(np.vstack([x, y]))
    xi, yi = np.mgrid[XMIN:XMAX:x.size**0.5*1j,YMIN:YMAX:y.size**0.5*1j]
    zi = k(np.vstack([xi.flatten(), yi.flatten()]))
    
    fig, ax = draw_pitch(title=f'Leo Meessi\'s Heatmap in La Liga {season_list[0]}~{season_list[-1]} via statsbomb' if len(season_list)!=1 else f'Leo Meessi\'s Heatmap in La Liga {season_list[0]} via statsbomb')
    
    ax.contourf(xi, yi, zi.reshape(xi.shape), alpha=0.3)
#     ax.contourf(xi, yi, zi.reshape(xi.shape), alpha=0.3, cmap='YlOrBr')
#     ax.contourf(xi, yi, zi.reshape(xi.shape), alpha=0.3, levels=4, colors=[twitter_color]+color_list)
#     ax.contour(xi, yi, zi.reshape(xi.shape), alpha=0.3, cmap='YlOrBr')

    plt.savefig(os.path.join('..','fig',f'heatmap_{convert_season_name(season_list[0])}~{convert_season_name(season_list[-1])}.png' if len(season_list)!=1 else f'heatmap_{convert_season_name(season_list[0])}.png'), bbox_inches='tight', facecolor=twitter_color)
